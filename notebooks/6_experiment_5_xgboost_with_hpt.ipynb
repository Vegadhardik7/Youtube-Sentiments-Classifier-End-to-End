# %%
import mlflow
# Step 2: Set up the MLflow tracking server
mlflow.set_tracking_uri("http://ec2-13-221-127-40.compute-1.amazonaws.com:5000/")

# %%
# Set or create an experiment
mlflow.set_experiment("Exp 5 - ML Algos with HP Tuning")
# Out:
# 2025/12/12 12:01:13 INFO mlflow.tracking.fluent: Experiment with name 'Exp 5 - ML Algos with HP Tuning' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://mlflow-bucket-youtube-sentiments-classifier/5', creation_time=1765521074331, experiment_id='5', last_update_time=1765521074331, lifecycle_stage='active', name='Exp 5 - ML Algos with HP Tuning', tags={}>

# %%
import optuna
import mlflow
import mlflow.sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('reddit_preprocessing.csv').dropna()
df.shape
# Out:
# (36662, 2)

# %%
# Step 1: Remap the class labels from [-1, 0, 1] to [2, 0, 1]
df['category'] = df['category'].map({-1: 2, 0: 0, 1: 1})

# Step 2: Remove rows where the target labels (category) are NaN
df = df.dropna(subset=['category'])

ngram_range = (1, 3)  # Trigram setting
max_features = 10000  # Set max_features to 1000 for TF-IDF

# Step 4: Train-test split before vectorization and resampling
X_train, X_test, y_train, y_test = train_test_split(df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

# Step 2: Vectorization using TF-IDF, fit on training data only
vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)
X_train_vec = vectorizer.fit_transform(X_train)  # Fit on training data
X_test_vec = vectorizer.transform(X_test)  # Transform test data

smote = SMOTE(random_state=42)
X_train_vec, y_train = smote.fit_resample(X_train_vec, y_train)

# Function to log results in MLflow
def log_mlflow(model_name, model, X_train, X_test, y_train, y_test):
    with mlflow.start_run():
        # Log model type
        mlflow.set_tag("mlflow.runName", f"{model_name}_SMOTE_TFIDF_Trigrams")
        mlflow.set_tag("experiment_type", "algorithm_comparison")

        # Log algorithm name as a parameter
        mlflow.log_param("algo_name", model_name)

        # Train model
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log the model
        mlflow.sklearn.log_model(model, f"{model_name}_model")


# Step 6: Optuna objective function for XGBoost
def objective_xgboost(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True)
    max_depth = trial.suggest_int('max_depth', 3, 10)

    model = XGBClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, random_state=42)
    return accuracy_score(y_test, model.fit(X_train_vec, y_train).predict(X_test_vec))


# Step 7: Run Optuna for XGBoost, log the best model only
def run_optuna_experiment():
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_xgboost, n_trials=30)

    # Get the best parameters and log only the best model
    best_params = study.best_params
    best_model = XGBClassifier(n_estimators=best_params['n_estimators'], learning_rate=best_params['learning_rate'], max_depth=best_params['max_depth'], random_state=42)

    # Log the best model with MLflow, passing the algo_name as "xgboost"
    log_mlflow("XGBoost", best_model, X_train_vec, X_test_vec, y_train, y_test)

# Run the experiment for XGBoost
run_optuna_experiment()
# Out:
# [I 2025-12-12 12:17:34,399] A new study created in memory with name: no-name-575db050-9274-42b8-a369-fb69ce0528a7
# [I 2025-12-12 12:17:47,640] Trial 0 finished with value: 0.49679530887767626 and parameters: {'n_estimators': 75, 'learning_rate': 0.00027066475164193266, 'max_depth': 3}. Best is trial 0 with value: 0.49679530887767626.
# [I 2025-12-12 12:22:38,715] Trial 1 finished with value: 0.6394381562798309 and parameters: {'n_estimators': 271, 'learning_rate': 0.0038781469131947046, 'max_depth': 8}. Best is trial 1 with value: 0.6394381562798309.
# [I 2025-12-12 12:24:02,869] Trial 2 finished with value: 0.6139369971362335 and parameters: {'n_estimators': 58, 'learning_rate': 0.0019674670922806645, 'max_depth': 9}. Best is trial 1 with value: 0.6394381562798309.
# [I 2025-12-12 12:26:26,271] Trial 3 finished with value: 0.6939860902768308 and parameters: {'n_estimators': 240, 'learning_rate': 0.019793289208067884, 'max_depth': 6}. Best is trial 3 with value: 0.6939860902768308.
# [I 2025-12-12 12:26:52,181] Trial 4 finished with value: 0.7083049229510432 and parameters: {'n_estimators': 149, 'learning_rate': 0.0853176458347426, 'max_depth': 3}. Best is trial 4 with value: 0.7083049229510432.
# [I 2025-12-12 12:31:10,571] Trial 5 finished with value: 0.6780308195827083 and parameters: {'n_estimators': 216, 'learning_rate': 0.012231131254850347, 'max_depth': 8}. Best is trial 4 with value: 0.7083049229510432.
# [I 2025-12-12 12:32:45,728] Trial 6 finished with value: 0.6930315014318833 and parameters: {'n_estimators': 67, 'learning_rate': 0.04430285508057699, 'max_depth': 9}. Best is trial 4 with value: 0.7083049229510432.
# [I 2025-12-12 12:34:32,636] Trial 7 finished with value: 0.576708032183281 and parameters: {'n_estimators': 171, 'learning_rate': 0.0018796087680569224, 'max_depth': 6}. Best is trial 4 with value: 0.7083049229510432.
# [I 2025-12-12 12:35:45,881] Trial 8 finished with value: 0.5773898813582435 and parameters: {'n_estimators': 86, 'learning_rate': 0.00021333637634377519, 'max_depth': 7}. Best is trial 4 with value: 0.7083049229510432.
# [I 2025-12-12 12:36:36,247] Trial 9 finished with value: 0.5577526251193236 and parameters: {'n_estimators': 81, 'learning_rate': 0.00038256264387591914, 'max_depth': 6}. Best is trial 4 with value: 0.7083049229510432.
# [I 2025-12-12 12:37:01,153] Trial 10 finished with value: 0.7178508114005182 and parameters: {'n_estimators': 161, 'learning_rate': 0.09604727556055428, 'max_depth': 3}. Best is trial 10 with value: 0.7178508114005182.
# [I 2025-12-12 13:05:06,639] Trial 26 finished with value: 0.6579844538388109 and parameters: {'n_estimators': 218, 'learning_rate': 0.007893277290009633, 'max_depth': 8}. Best is trial 25 with value: 0.7653075139779081.
# [I 2025-12-12 13:07:46,015] Trial 27 finished with value: 0.7663984726578481 and parameters: {'n_estimators': 182, 'learning_rate': 0.058924049181540275, 'max_depth': 9}. Best is trial 27 with value: 0.7663984726578481.
# [I 2025-12-12 13:12:33,779] Trial 28 finished with value: 0.7204418382653757 and parameters: {'n_estimators': 250, 'learning_rate': 0.019483262926657877, 'max_depth': 9}. Best is trial 27 with value: 0.7663984726578481.
# [I 2025-12-12 13:14:24,172] Trial 29 finished with value: 0.7481249147688531 and parameters: {'n_estimators': 189, 'learning_rate': 0.053970647280593094, 'max_depth': 7}. Best is trial 27 with value: 0.7663984726578481.
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connection.py:500, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     499     self.putheader(header, value)
# --> 500 self.endheaders()
#     502 # If we're given a body we start sending that in chunks.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:975, in HTTPConnection.send(self, data)
#     974 if self.auto_open:
# --> 975     self.connect()
#     976 else:
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connection.py:331, in HTTPConnection.connect(self)
#     330 def connect(self) -> None:
# --> 331     self.sock = self._new_conn()
#     332     if self._tunnel_host:
#     333         # If we're tunneling it means we're connected to our proxy.
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connection.py:219, in HTTPConnection._new_conn(self)
#     218 except OSError as e:
# --> 219     raise NewConnectionError(
#     220         self, f"Failed to establish a new connection: {e}"
#     221     ) from e
#     223 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: HTTPConnection(host='ec2-13-221-127-40.compute-1.amazonaws.com', port=5000): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 871 (2 times)]
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='ec2-13-221-127-40.compute-1.amazonaws.com', port=5000): Max retries exceeded with url: /api/2.0/mlflow/runs/create (Caused by NewConnectionError("HTTPConnection(host='ec2-13-221-127-40.compute-1.amazonaws.com', port=5000): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\mlflow\utils\rest_utils.py:189, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     188 try:
# --> 189     return _get_http_response_with_retries(
#     190         method,
#     191         url,
#     192         max_retries,
#     193         backoff_factor,
#     194         backoff_jitter,
#     195         retry_codes,
#     196         raise_on_status,
#     197         headers=headers,
#     198         verify=host_creds.verify,
#     199         timeout=timeout,
#     200         respect_retry_after_header=respect_retry_after_header,
#     201         **kwargs,
#     202     )
#     203 except requests.exceptions.Timeout as to:
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\mlflow\utils\request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\requests\adapters.py:677, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     675         raise SSLError(e, request=request)
# --> 677     raise ConnectionError(e, request=request)
#     679 except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='ec2-13-221-127-40.compute-1.amazonaws.com', port=5000): Max retries exceeded with url: /api/2.0/mlflow/runs/create (Caused by NewConnectionError("HTTPConnection(host='ec2-13-221-127-40.compute-1.amazonaws.com', port=5000): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it"))
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[8], line 73
#      70     log_mlflow("XGBoost", best_model, X_train_vec, X_test_vec, y_train, y_test)
#      72 # Run the experiment for XGBoost
# ---> 73 run_optuna_experiment()
#
# Cell In[8], line 70, in run_optuna_experiment()
#      67 best_model = XGBClassifier(n_estimators=best_params['n_estimators'], learning_rate=best_params['learning_rate'], max_depth=best_params['max_depth'], random_state=42)
#      69 # Log the best model with MLflow, passing the algo_name as "xgboost"
# ---> 70 log_mlflow("XGBoost", best_model, X_train_vec, X_test_vec, y_train, y_test)
#
# Cell In[8], line 23, in log_mlflow(model_name, model, X_train, X_test, y_train, y_test)
#      22 def log_mlflow(model_name, model, X_train, X_test, y_train, y_test):
# ---> 23     with mlflow.start_run():
#      24         # Log model type
#      25         mlflow.set_tag("mlflow.runName", f"{model_name}_SMOTE_TFIDF_Trigrams")
#      26         mlflow.set_tag("experiment_type", "algorithm_comparison")
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\mlflow\tracking\fluent.py:418, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     414         user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     416     resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> 418     active_run_obj = client.create_run(
#     419         experiment_id=exp_id_for_run,
#     420         tags=resolved_tags,
#     421         run_name=run_name,
#     422     )
#     424 if log_system_metrics is None:
#     425     # If `log_system_metrics` is not specified, we will check environment variable.
#     426     log_system_metrics = MLFLOW_ENABLE_SYSTEM_METRICS_LOGGING.get()
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\mlflow\tracking\client.py:393, in MlflowClient.create_run(self, experiment_id, start_time, tags, run_name)
#     339 def create_run(
#     340     self,
#     341     experiment_id: str,
#    (...)    344     run_name: Optional[str] = None,
#     345 ) -> Run:
#     346     """
#     347     Create a :py:class:`mlflow.entities.Run` object that can be associated with
#     348     metrics, parameters, artifacts, etc.
#    (...)    391         status: RUNNING
#     392     """
# --> 393     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:168, in TrackingServiceClient.create_run(self, experiment_id, start_time, tags, run_name)
#     163 # Extract user from tags
#     164 # This logic is temporary; the user_id attribute of runs is deprecated and will be removed
#     165 # in a later release.
#     166 user_id = tags.get(MLFLOW_USER, "unknown")
# --> 168 return self.store.create_run(
#     169     experiment_id=experiment_id,
#     170     user_id=user_id,
#     171     start_time=start_time or get_current_time_millis(),
#     172     tags=[RunTag(key, value) for (key, value) in tags.items()],
#     173     run_name=run_name,
#     174 )
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\mlflow\store\tracking\rest_store.py:209, in RestStore.create_run(self, experiment_id, user_id, start_time, tags, run_name)
#     199 tag_protos = [tag.to_proto() for tag in tags]
#     200 req_body = message_to_json(
#     201     CreateRun(
#     202         experiment_id=str(experiment_id),
#    (...)    207     )
#     208 )
# --> 209 response_proto = self._call_endpoint(CreateRun, req_body)
#     210 return Run.from_proto(response_proto.run)
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\mlflow\store\tracking\rest_store.py:82, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      80     endpoint, method = _METHOD_TO_INFO[api]
#      81 response_proto = api.Response()
# ---> 82 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\mlflow\utils\rest_utils.py:368, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     366 else:
#     367     call_kwargs["json"] = json_body
# --> 368     response = http_request(**call_kwargs)
#     370 response = verify_rest_response(response, endpoint)
#     371 response_to_parse = response.text
#
# File D:\Youtube-Sentiments-Classifier-End-to-End\.venv\Lib\site-packages\mlflow\utils\rest_utils.py:212, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     210     raise InvalidUrlException(f"Invalid url: {url}") from iu
#     211 except Exception as e:
# --> 212     raise MlflowException(f"API request to {url} failed with exception {e}")
#
# MlflowException: API request to http://ec2-13-221-127-40.compute-1.amazonaws.com:5000/api/2.0/mlflow/runs/create failed with exception HTTPConnectionPool(host='ec2-13-221-127-40.compute-1.amazonaws.com', port=5000): Max retries exceeded with url: /api/2.0/mlflow/runs/create (Caused by NewConnectionError("HTTPConnection(host='ec2-13-221-127-40.compute-1.amazonaws.com', port=5000): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it"))
